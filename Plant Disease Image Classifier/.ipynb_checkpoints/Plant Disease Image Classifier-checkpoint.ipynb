# %%
import random
random.seed(0)

# %%
import numpy as np
np.random.seed(0)

# %%
import tensorflow as tf
tf.random.set_seed(0)

# %%
# Importing the dependencies
import os
import json # to load the kaggle.json file
from zipfile import ZipFile
from PIL import Image # use to do some image processing works

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # to display an image
from tensorflow.keras.preprocessing.image import ImageDataGenerator # like the data pipelines that we will set for training data and testing data 
from tensorflow.keras import layers, models # layers are used for get CNN, flatten, dense layers.  Models is used to import sequential from these models

# %% [markdown]
# # Data Curation

# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import shutil

# %%
cache_path = kagglehub.dataset_download("abdallahalidev/plantvillage-dataset")
# Out:
# ...
# 100%|█████████████████████████████████| 2.04G/2.04G [17:48<00:00, 2.05MB/s]
# Extracting files...

# %%
dataset_folder = "./plantvillage"

if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)
shutil.copytree(cache_path, dataset_folder, dirs_exist_ok=True)
# Out:
# './plantvillage'

# %%
print(os.listdir('plantvillage/plantvillage dataset'))
# Out:
# ['color', 'grayscale', 'segmented']

# %%
print(len(os.listdir('plantvillage/plantvillage dataset/segmented')))
print(os.listdir('plantvillage/plantvillage dataset/segmented')[:5])
# Out:
# 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy']

# %%
print(len(os.listdir('plantvillage/plantvillage dataset/color')))
print(os.listdir('plantvillage/plantvillage dataset/color')[:5])
# Out:
# 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy']

# %%
print(len(os.listdir('plantvillage/plantvillage dataset/grayscale')))
print(os.listdir('plantvillage/plantvillage dataset/grayscale')[:5])
# Out:
# 38
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy']

# %% [markdown]
# * Number of classes = 38

# %%
print(len(os.listdir('plantvillage/plantvillage dataset/color/Grape___healthy')))
print(os.listdir('plantvillage/plantvillage dataset/color/Grape___healthy')[:5])
# Out:
# 423
# ['00e00912-bf75-4cf8-8b7d-ad64b73bea5f___Mt.N.V_HL 6067.JPG', '0163a6aa-fbf8-47c5-965f-59b6efe8bfe5___Mt.N.V_HL 6103.JPG', '0294ca65-4c29-44be-af28-501df9f715e8___Mt.N.V_HL 6176.JPG', '02f95acb-5d92-4f2a-b7ec-3af8709ee7c9___Mt.N.V_HL 9078.JPG', '03027791-26bb-4c46-960e-8df76e27042c___Mt.N.V_HL 6070.JPG']

# %% [markdown]
# # Data Preprocessing for color images

# %%
# Dataset Path
base_dir = "plantvillage/plantvillage dataset/color"

# %%
image_path = "plantvillage/plantvillage dataset/color/Apple___healthy/00a6039c-e425-4f7d-81b1-d6b0e668517e___RS_HL 7669.JPG"

# Read the image
img = mpimg.imread(image_path)

print(img.shape)

# display the image
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# (256, 256, 3)

# %%
# resize the all images with same parameters
img_size = 224
batch_size = 32

# %% [markdown]
# # Train Test Split

# %%
# image data generators
data_gen = ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.2 #Use 20% of data for validation
)

# %%
# Train Generator
train_generator = data_gen.flow_from_directory(
    base_dir,
    target_size = (img_size, img_size),
    batch_size = batch_size,
    subset='training',
    class_mode = "categorical"
)
# Out:
# Found 43456 images belonging to 38 classes.

# %%
# Validation Generator
validation_generator = data_gen.flow_from_directory(
    base_dir,
    target_size = (img_size, img_size),
    batch_size = batch_size,
    subset='validation',
    class_mode = "categorical"
)
# Out:
# Found 10849 images belonging to 38 classes.

# %% [markdown]
# # Convolutional Neural Network

# %%
# Model Definition
model = models.Sequential()

model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(img_size,img_size,3)))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(train_generator.num_classes, activation = 'softmax'))

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape          ┃      Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)             │ (None, 222, 222, 32)  │          896 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_2               │ (None, 111, 111, 32)  │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 109, 109, 64)  │       18,496 │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# │ max_pooling2d_3               │ (None, 54, 54, 64)    │            0 │
# │ (MaxPooling2D)                │                       │              │
# ├───────────────────────────────┼───────────────────────┼──────────────┤
# ...

# %%
# Compile the model
model.compile(optimizer = 'adam',
             loss = 'categorical_crossentropy',
             metrics =['accuracy'])

# %% [markdown]
# # Model Training

# %%
# Training the Model
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size, # Number of steps per epoch
    epochs = 5,
    validation_data = validation_generator,
    validation_steps = validation_generator.samples // batch_size # Validation steps
)
# Out:
# Epoch 1/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 1208s 888ms/step - accuracy: 0.7428 - loss: 0.9147 - val_accuracy: 0.8537 - val_loss: 0.4620
# Epoch 2/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 1157s 852ms/step - accuracy: 0.9152 - loss: 0.2647 - val_accuracy: 0.8564 - val_loss: 0.4767
# Epoch 3/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 1202s 885ms/step - accuracy: 0.9596 - loss: 0.1209 - val_accuracy: 0.8729 - val_loss: 0.4929
# Epoch 4/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 1168s 860ms/step - accuracy: 0.9727 - loss: 0.0841 - val_accuracy: 0.8609 - val_loss: 0.5856
# Epoch 5/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 1179s 868ms/step - accuracy: 0.9787 - loss: 0.0668 - val_accuracy: 0.8548 - val_loss: 0.6888

# %% [markdown]
# # Model Evaluation

# %%
# Model Evaluation
print("Model Evaluation...")
val_loss, val_accuracy = model.evaluate(validation_generator, steps = validation_generator.samples // batch_size)
print(f"Validation Accuracy: {val_accuracy* 100:.2f}%")
# Out:
# Model Evaluation...
# 339/339 ━━━━━━━━━━━━━━━━━━━━ 53s 156ms/step - accuracy: 0.8548 - loss: 0.6888
# Validation Accuracy: 85.48%

# %%
# plot training & validation accuracy values
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

#plot training and validatilon loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Trian','Test'], loc='upper left')
plt.show()

# %%
# Building a Predictive System
def load_and_preprocess_image(image_path, target_size=(224,224)) :
    # Load the image
    img = Image.open(image_path)
    # Resize the image
    img = img.resize(target_size)
    # convert the image to a numpy array
    img_array = np.array(img)
    # Add batch dimension
    img_array = np.expand_dims(img_array, axis=0)
    # Scale the image values to [0,1]
    img_array = img_array.astype('float32')/255.
    return img_array

# Function to Predict the Class of an Image
def predict_image_class(model, image_path, class_indices):
    preprocessed_img = load_and_preprocess_image(image_path)
    predictions = model.predict(preprocessed_img)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_class_name = class_indices[predicted_class_index]
    return predicted_class_name

# %%
# Create a mapping from class indices to class names
class_indices = {v: k for k, v in train_generator.class_indices.items()}

# %%
class_indices
# Out:
# {0: 'Apple___Apple_scab',
#  1: 'Apple___Black_rot',
#  2: 'Apple___Cedar_apple_rust',
#  3: 'Apple___healthy',
#  4: 'Blueberry___healthy',
#  5: 'Cherry_(including_sour)___Powdery_mildew',
#  6: 'Cherry_(including_sour)___healthy',
#  7: 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  8: 'Corn_(maize)___Common_rust_',
#  9: 'Corn_(maize)___Northern_Leaf_Blight',
#  10: 'Corn_(maize)___healthy',
#  11: 'Grape___Black_rot',
#  12: 'Grape___Esca_(Black_Measles)',
#  13: 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  14: 'Grape___healthy',
#  15: 'Orange___Haunglongbing_(Citrus_greening)',
#  16: 'Peach___Bacterial_spot',
#  17: 'Peach___healthy',
#  18: 'Pepper,_bell___Bacterial_spot',
#  19: 'Pepper,_bell___healthy',
#  20: 'Potato___Early_blight',
#  21: 'Potato___Late_blight',
#  22: 'Potato___healthy',
#  23: 'Raspberry___healthy',
#  24: 'Soybean___healthy',
#  25: 'Squash___Powdery_mildew',
#  26: 'Strawberry___Leaf_scorch',
#  27: 'Strawberry___healthy',
# ...

# %%
# saving the class names as json file
json.dump(class_indices, open('class_indices.json','w'))

# %%
#Example Usage
#image_path = "Apple_scab.JPG"
image_path = "peach_healthy.JPG"
predicted_class_name = predict_image_class(model, image_path, class_indices)

# Output the result
print("Predicted Class Name: ", predicted_class_name)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Predicted Class Name:  Peach___healthy

# %% [markdown]
# # Save the model
